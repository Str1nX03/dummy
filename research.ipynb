# %%
from llms.llm import ollama_llm

llm = ollama_llm()
prompt = "Hey, I am Dravin."
response = llm.invoke(prompt)

# %%
response.content
# Out:
# 'Hey Dravin! It’s nice to meet you. 😊 What’s up? Is there anything you’d like to chat about?'
